# %% [markdown]
# # Working on Real Project in Python

# %% [markdown]
# # A Part Of Big Data Analysis

# %% [markdown]
# # The SuperStore_Sales_Dataset

# %% [markdown]
# # Import Data Set

# %%
import pandas as pd

# %%
SuperStore = pd.read_csv('SuperStore_Sales_Dataset.csv')

# %% [markdown]
# # How to Analysis DataFrames

# %% [markdown]
# # .head() Method

# %%
SuperStore.head(2)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 1  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#     Sales Quantity   Profit  Returns  Payment Mode  ind1  ind2
# 0   73.94        1  28.2668      NaN        Online   NaN   NaN
# 1  173.94        3  38.2668      NaN        Online   NaN   NaN
#
# [2 rows x 23 columns]

# %%
SuperStore.tail(2)
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name   Segment        Country  \
# 5899  Standard Class    PO-18865  Patrick O'Donnell  Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias  Consumer  United States
#
#                City  ...         Category Sub-Category  \
# 5899  New York City  ...  Office Supplies      Binders
# 5900       Loveland  ...  Office Supplies    Fasteners
#
#                               Product Name     Sales Quantity   Profit  \
# 5899  Wilson Jones Legal Size Ring Binders   462.776        3  19.7910
# 5900                   Bagged Rubber Bands  2975.510        3  -0.6048
#
#       Returns  Payment Mode  ind1  ind2
# 5899      NaN           COD   NaN   NaN
# 5900      NaN           COD   NaN   NaN
#
# [2 rows x 23 columns]

# %% [markdown]
# # .shape Method

# %%
SuperStore.shape
# Out:
# (5901, 23)

# %% [markdown]
# # .Index Method

# %%
SuperStore.index
# Out:
# RangeIndex(start=0, stop=5901, step=1)

# %% [markdown]
# # .columns Method

# %%
SuperStore.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode', 'ind1',
#        'ind2'],
#       dtype='object')

# %% [markdown]
# # .dtypes Method

# %%
SuperStore.dtypes
# Out:
# Row ID+O6G3A1:R6      int64
# Order ID             object
# Order Date           object
# Ship Date            object
# Ship Mode            object
# Customer ID          object
# Customer Name        object
# Segment              object
# Country              object
# City                 object
# State                object
# Region               object
# Product ID           object
# Category             object
# Sub-Category         object
# Product Name         object
# Sales               float64
# Quantity              int64
# Profit              float64
# Returns             float64
# Payment Mode         object
# ind1                float64
# ind2                float64
# dtype: object

# %% [markdown]
# # .counts

# %%
SuperStore.count()
# Out:
# Row ID+O6G3A1:R6    5901
# Order ID            5901
# Order Date          5901
# Ship Date           5901
# Ship Mode           5901
# Customer ID         5901
# Customer Name       5901
# Segment             5901
# Country             5901
# City                5901
# State               5901
# Region              5901
# Product ID          5901
# Category            5901
# Sub-Category        5901
# Product Name        5901
# Sales               5901
# Quantity            5901
# Profit              5901
# Returns              287
# Payment Mode        5901
# ind1                   0
# ind2                   0
# dtype: int64

# %% [markdown]
# # value_counts() Method

# %%
SuperStore.head(1)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#    Sales Quantity   Profit  Returns  Payment Mode  ind1  ind2
# 0  73.94        1  28.2668      NaN        Online   NaN   NaN
#
# [1 rows x 23 columns]

# %%
SuperStore['Product Name'].value_counts().head(10)
# Out:
# Easy-staple paper                                  27
# Staples                                            24
# Staple envelope                                    22
# Staples in misc. colors                            13
# Chromcraft Round Conference Tables                 12
# Storex Dura Pro Binders                            12
# Staple remover                                     12
# Avery Non-Stick Binders                            11
# Global Wood Trimmed Manager's Task Chair, Khaki    11
# GBC Instant Report Kit                             10
# Name: Product Name, dtype: int64

# %%
SuperStore['City'].value_counts().head(70)
# Out:
# New York City    563
# Los Angeles      430
# Philadelphia     310
# San Francisco    304
# Seattle          282
#                 ...
# Glendale          16
# Tulsa             16
# Inglewood         16
# Quincy            15
# Wilmington        15
# Name: City, Length: 70, dtype: int64

# %%
SuperStore['Category'].value_counts().head(4)
# Out:
# Office Supplies    3569
# Furniture          1249
# Technology         1083
# Name: Category, dtype: int64

# %%
SuperStore['Customer Name'].value_counts().head(100)
# Out:
# Emily Phan           27
# Seth Vernon          25
# Paul Prost           25
# Edward Hooks         25
# Pete Kriz            24
#                      ..
# Joel Eaton           13
# Todd Boyes           13
# Maris LaWare         13
# Cassandra Brandow    13
# Eric Hoffmann        13
# Name: Customer Name, Length: 100, dtype: int64

# %% [markdown]
# # .info Method()

# %%
SuperStore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
# ...

# %% [markdown]
# # Find the number of times when the 'Product Name' Exactly Staples

# %%
SuperStore.head(1)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#    Sales Quantity   Profit  Returns  Payment Mode  ind1  ind2
# 0  73.94        1  28.2668      NaN        Online   NaN   NaN
#
# [1 rows x 23 columns]

# %%
SuperStore['Product Name'].value_counts()
# Out:
# Easy-staple paper                               27
# Staples                                         24
# Staple envelope                                 22
# Staples in misc. colors                         13
# Chromcraft Round Conference Tables              12
#                                                 ..
# Sony 8GB Class 10 Micro SDHC R40 Memory Card     1
# Letter Slitter                                   1
# Avery 479                                        1
# OIC Thumb-Tacks                                  1
# Acco Glide Clips                                 1
# Name: Product Name, Length: 1742, dtype: int64

# %%
SuperStore[SuperStore['Product Name']=='Staples'].head(5)
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 172               9063  CA-2019-101623  28-02-2019  06-03-2019
# 342                647  CA-2019-103947  01-04-2019  08-04-2019
# 1110              5679  CA-2019-143924  28-07-2019  03-08-2019
# 1279              3346  CA-2019-145982  27-08-2019  01-09-2019
# 1315              2145  CA-2019-155481  01-09-2019  05-09-2019
#
#            Ship Mode Customer ID    Customer Name      Segment        Country  \
# 172   Standard Class    RR-19525        Rick Reed    Corporate  United States
# 342   Standard Class    BB-10990  Barry Blumstein    Corporate  United States
# 1110  Standard Class    SC-20680    Steve Carroll  Home Office  United States
# 1279    Second Class    TB-21055  Ted Butterfield     Consumer  United States
# 1315  Standard Class    DK-13225        Dean Katz    Corporate  United States
#
#                City  ...         Category Sub-Category Product Name   Sales  \
# ...

# %% [markdown]
# # Find the number of times when the 'Sub-Category' Copiers Exactly

# %%
SuperStore['Sub-Category'].value_counts()
# Out:
# Binders        915
# Paper          825
# Furnishings    573
# Phones         519
# Storage        498
# Art            465
# Accessories    461
# Chairs         355
# Appliances     279
# Labels         211
# Tables         190
# Envelopes      133
# Bookcases      131
# Fasteners      124
# Supplies       119
# Machines        65
# Copiers         38
# Name: Sub-Category, dtype: int64

# %%
SuperStore[SuperStore['Sub-Category']=='Copiers']
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 9                 2898  US-2019-164630  04-01-2019  09-01-2019
# 368                754  CA-2019-110499  07-04-2019  09-04-2019
# 650               6426  CA-2019-143714  23-05-2019  27-05-2019
# 706               1234  CA-2019-153682  30-05-2019  01-06-2019
# 933               7473  CA-2019-139997  01-07-2019  03-07-2019
# 960               3984  CA-2019-135265  07-07-2019  09-07-2019
# 1095              1987  CA-2019-147417  25-07-2019  27-07-2019
# 1342              8179  CA-2019-166429  02-09-2019  08-09-2019
# 1383              9930  CA-2019-129630  04-09-2019  04-09-2019
# 1471              4640  CA-2019-102162  11-09-2019  16-09-2019
# 1631              9840  US-2019-125402  25-09-2019  01-10-2019
# 1681              6827  CA-2019-118689  02-10-2019  09-10-2019
# 1694              7667  US-2019-140158  04-10-2019  08-10-2019
# 2053              4813  CA-2019-121370  14-11-2019  19-11-2019
# ...

# %% [markdown]
# # Find out all the the null values in the data

# %%
SuperStore.head(1)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#    Sales Quantity   Profit  Returns  Payment Mode  ind1  ind2
# 0  73.94        1  28.2668      NaN        Online   NaN   NaN
#
# [1 rows x 23 columns]

# %%
SuperStore.isnull().head(10)
# Out:
#    Row ID+O6G3A1:R6  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0             False     False       False      False      False        False
# 1             False     False       False      False      False        False
# 2             False     False       False      False      False        False
# 3             False     False       False      False      False        False
# 4             False     False       False      False      False        False
# 5             False     False       False      False      False        False
# 6             False     False       False      False      False        False
# 7             False     False       False      False      False        False
# 8             False     False       False      False      False        False
# 9             False     False       False      False      False        False
#
#    Customer Name  Segment  Country   City  ...  Category  Sub-Category  \
# ...

# %%
SuperStore.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %% [markdown]
# # Rename the column name 'Weather'of the data frame 'Weather Condition'

# %%
SuperStore.head(2)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 1  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#     Sales Quantity   Profit  Returns  Payment Mode  ind1  ind2
# 0   73.94        1  28.2668      NaN        Online   NaN   NaN
# 1  173.94        3  38.2668      NaN        Online   NaN   NaN
#
# [2 rows x 23 columns]

# %%
SuperStore.rename(columns={'ind1':'Hamza'},inplace=True)
SuperStore.head(2)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 1  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#     Sales Quantity   Profit  Returns  Payment Mode  Hamza  ind2
# 0   73.94        1  28.2668      NaN        Online    NaN   NaN
# 1  173.94        3  38.2668      NaN        Online    NaN   NaN
#
# [2 rows x 23 columns]

# %% [markdown]
# # What is Profit mean

# %%
SuperStore.head(2)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
# 1  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#     Sales Quantity   Profit  Returns  Payment Mode  Hamza  ind2
# 0   73.94        1  28.2668      NaN        Online    NaN   NaN
# 1  173.94        3  38.2668      NaN        Online    NaN   NaN
#
# [2 rows x 23 columns]

# %%
SuperStore.Profit.mean()
# Out:
# 29.70040771055753

# %% [markdown]
# # What is Sales Profit mean

# %%
SuperStore.Sales.mean()
# Out:
# 265.3455894255211

# %% [markdown]
# # What is standard Deviation 'Sales'in the data

# %%
SuperStore.Sales.std()
# Out:
# 474.260645476471

# %% [markdown]
# # What is the variance of 'Profit'in this data

# %%
SuperStore.Profit.var()
# Out:
# 67386.52075655355

# %% [markdown]
# # Find all instance when 'Sales'above 100 and 'Quantity 4 '

# %%
SuperStore.head(1)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#    Sales Quantity   Profit  Returns  Payment Mode  Hamza  ind2
# 0  73.94        1  28.2668      NaN        Online    NaN   NaN
#
# [1 rows x 23 columns]

# %%
SuperStore[(SuperStore['Sales'] >100) & (SuperStore['Quantity']==4)]
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 9                 2898  US-2019-164630  04-01-2019  09-01-2019
# 48                2303  CA-2019-106558  17-01-2019  21-01-2019
# 53                2472  US-2019-135923  22-01-2019  28-01-2019
# 59                6229  CA-2019-148208  22-01-2019  27-01-2019
# 78                7565  US-2019-166660  30-01-2019  01-02-2019
# ...                ...             ...         ...         ...
# 5861              2571  CA-2020-134404  27-12-2020  27-12-2020
# 5867               271  CA-2020-163979  28-12-2020  02-01-2021
# 5877               572  CA-2020-164826  28-12-2020  04-01-2021
# 5886              1878  CA-2020-118885  29-12-2020  02-01-2021
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
#
#            Ship Mode Customer ID      Customer Name      Segment  \
# 9     Standard Class    EB-13975         Erica Bern    Corporate
# 48    Standard Class    DL-13495       Dionis Lloyd    Corporate
# ...

# %% [markdown]
# # What is the mean value of each columns against each 'SuperStore'

# %%
SuperStore.head(1)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#    Sales Quantity   Profit  Returns  Payment Mode  Hamza  ind2
# 0  73.94        1  28.2668      NaN        Online    NaN   NaN
#
# [1 rows x 23 columns]

# %%
SuperStore.groupby('Country').mean()
# Out:
# C:\Users\HAMZA\AppData\Local\Temp\ipykernel_9160\3890252815.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   SuperStore.groupby('Country').mean()
#                Row ID+O6G3A1:R6       Sales  Quantity     Profit  Returns  \
# Country
# United States       5022.422471  265.345589  3.781901  29.700408      1.0
#
#                Hamza  ind2
# Country
# United States    NaN   NaN

# %%
SuperStore.groupby('Product Name').mean().head(5)
# Out:
# C:\Users\HAMZA\AppData\Local\Temp\ipykernel_9160\3096509278.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   SuperStore.groupby('Product Name').mean().head(5)
#                                                     Row ID+O6G3A1:R6  \
# Product Name
# "While you Were Out" Message Book, One Form per...       4271.333333
# #10 Gummed Flap White Envelopes, 100/Box                 3975.333333
# #10 Self-Seal White Envelopes                            3763.250000
# #10 White Business Envelopes,4 1/8 x 9 1/2               7256.750000
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                  3050.666667
#
#                                                        Sales  Quantity  \
# Product Name
# "While you Were Out" Message Book, One Form per...  103.0760  2.666667
# ...

# %% [markdown]
# # What is the minimum and maximum value of each columns against each 'Product Name'

# %%
SuperStore.head(1)
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
#
#   Customer ID  Customer Name    Segment        Country          City  ...  \
# 0    BM-11575  Brendan Murry  Corporate  United States  Gaithersburg  ...
#
#     Category Sub-Category                                       Product Name  \
# 0  Furniture    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...
#
#    Sales Quantity   Profit  Returns  Payment Mode  Hamza  ind2
# 0  73.94        1  28.2668      NaN        Online    NaN   NaN
#
# [1 rows x 23 columns]

# %%
SuperStore.groupby('Product Name').max().head(2)
# Out:
#                                                     Row ID+O6G3A1:R6  \
# Product Name
# "While you Were Out" Message Book, One Form per...              7322
# #10 Gummed Flap White Envelopes, 100/Box                        7828
#
#                                                           Order ID  \
# Product Name
# "While you Were Out" Message Book, One Form per...  CA-2020-167626
# #10 Gummed Flap White Envelopes, 100/Box            CA-2020-117114
#
#                                                     Order Date   Ship Date  \
# Product Name
# "While you Were Out" Message Book, One Form per...  30-10-2020  16-11-2020
# #10 Gummed Flap White Envelopes, 100/Box            31-10-2020  21-01-2019
#
#                                                          Ship Mode  \
# Product Name
# "While you Were Out" Message Book, One Form per...  Standard Class
# #10 Gummed Flap White Envelopes, 100/Box            Standard Class
#
# ...

# %%
SuperStore.groupby('Product Name').min().head(2)
# Out:
#                                                     Row ID+O6G3A1:R6  \
# Product Name
# "While you Were Out" Message Book, One Form per...              1709
# #10 Gummed Flap White Envelopes, 100/Box                         356
#
#                                                           Order ID  \
# Product Name
# "While you Were Out" Message Book, One Form per...  CA-2020-123491
# #10 Gummed Flap White Envelopes, 100/Box            CA-2019-137848
#
#                                                     Order Date   Ship Date  \
# Product Name
# "While you Were Out" Message Book, One Form per...  03-09-2020  05-11-2020
# #10 Gummed Flap White Envelopes, 100/Box            08-04-2019  05-11-2020
#
#                                                          Ship Mode  \
# Product Name
# "While you Were Out" Message Book, One Form per...    Second Class
# #10 Gummed Flap White Envelopes, 100/Box            Standard Class
#
# ...

# %% [markdown]
# # Find all instance when 'Product Name' and 'Profit' in above 3000

# %%
SuperStore['Product Name'].value_counts()
# Out:
# Easy-staple paper                               27
# Staples                                         24
# Staple envelope                                 22
# Staples in misc. colors                         13
# Chromcraft Round Conference Tables              12
#                                                 ..
# Sony 8GB Class 10 Micro SDHC R40 Memory Card     1
# Letter Slitter                                   1
# Avery 479                                        1
# OIC Thumb-Tacks                                  1
# Acco Glide Clips                                 1
# Name: Product Name, Length: 1742, dtype: int64

# %%
SuperStore[(SuperStore['Product Name'] == 'Staple envelope')& (SuperStore['Profit']<3000)].head(6)
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 87                7505  CA-2019-158043  31-01-2019  04-02-2019
# 167               2742  CA-2019-165015  25-02-2019  27-02-2019
# 239               3607  CA-2019-119683  12-03-2019  16-03-2019
# 566               1557  CA-2019-109176  09-05-2019  15-05-2019
# 1379              9073  CA-2019-142524  04-09-2019  08-09-2019
# 1396              3874  CA-2019-136231  05-09-2019  07-09-2019
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 87      Second Class    JK-15325  Jason Klamczynski  Corporate  United States
# 167     Second Class    BD-11725   Bruce Degenhardt   Consumer  United States
# 239     Second Class    CK-12595       Clytie Kelty   Consumer  United States
# 566   Standard Class    JW-16075         Julia West   Consumer  United States
# 1379  Standard Class    MB-18085         Mick Brown   Consumer  United States
# ...

# %%
SuperStore.fillna(0).head()
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 2              4920  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 3              3074  CA-2019-125206  03-01-2019  05-01-2019     First Class
# 4              8604  US-2019-116365  03-01-2019  08-01-2019  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
#           Category Sub-Category  \
# ...
